# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenKumar302k6/FOUNDATION-OF-MODERN-MACHINE-LEARNING-236Q1A4512/blob/main/Module8%20Lab%203%20-%20Applying%20Bayes%20Classifiers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-19 05:46:34--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   138MB/s    in 0.5s
#
# 2025-03-19 05:46:35 (138 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6713   1705.07774v2  The ADAM optimizer is exceedingly popular in t...    cs
# 22002   1310.5666v1  We consider discrete graphical models Markov w...  stat
# 22884  1710.01406v2  This work constructs a hypothesis test for det...  stat
# 22762  1706.01445v3  Bayesian optimization (BO) has become an effec...  stat
# 22105   1411.5799v2  Factor analysis provides linear factors that d...  stat
# ...             ...                                                ...   ...
# 35218  cs/0109042v2  Alarm correlation plays an important role in i...    cs
# 13867  1512.05702v2  We review several of the most widely used tech...    cs
# 21697   0906.4391v1  Selecting important features in non-linear or ...  stat
# 18681   1108.5794v1  In order to give appropriate semantics to qual...    cs
# 11729  1610.08166v1  A key barrier to making phonetic studies scala...  stat
#
#                                                    title  year  \
# 6713   Dissecting Adam: The Sign, Magnitude and Varia...  2017
# 22002  Distributed parameter estimation of discrete h...  2013
# 22884  Robust Hypothesis Test for Nonlinear Effect wi...  2017
# 22762  Batched Large-scale Bayesian Optimization in H...  2017
# 22105                              Group Factor Analysis  2014
# ...                                                  ...   ...
# 35218  Intelligent Search of Correlated Alarms from D...  2001
# 13867  Synthesis of recurrent neural networks for dyn...  2015
# 21697         KNIFE: Kernel Iterative Feature Extraction  2009
# 18681  A Constraint Logic Programming Approach for Co...  2011
# 11729  Automatic measurement of vowel duration via st...  2016
#
#                                                 keywords
# 6713   [optimizer, exceedingly, community, sometimes,...
# 22002  [graphical, distributed, likelihood, canonical...
# 22884  [constructs, hypothesis, detecting, generating...
# 22762  [optimization, effective, optimization, evalua...
# 22105  [relationships, individual, variables, classic...
# ...                                                  ...
# 35218  [correlation, important, improving, reliabilit...
# 13867  [techniques, recurrent, approximate, dynamical...
# 21697  [selecting, important, difficult, challenge, c...
# 18681  [appropriate, semantics, qualitative, conditio...
# 11729  [replicable, subjective, annotation, challenge...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6713     [optimizer, exceedingly, community, sometimes,...
# 22002    [graphical, distributed, likelihood, canonical...
# 22884    [constructs, hypothesis, detecting, generating...
# 22762    [optimization, effective, optimization, evalua...
# 22105    [relationships, individual, variables, classic...
#                                ...
# 25969    [classification, extracting, different, classi...
# 155      [functions, observations, reinforcement, algor...
# 15411    [automatic, contained, judgments, procurement,...
# 31064    [currently, segmentation, radiograpy, challeng...
# 17913    [applications, scheduling, molecular, reasonin...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8802 words.
# Out of those 4570 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3691e9ef-3d6b-4286-93a2-9ed479426352" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3691e9ef-3d6b-4286-93a2-9ed479426352")) {                    Plotly.newPlot(                        "3691e9ef-3d6b-4286-93a2-9ed479426352",                        [{"x":["interpret","sometimes","disentangle","problematic","optimizer","magnitude","underlying","exceedingly","combination","isolation","practitioners","gradients","community","completing","generalization","mechanisms","determined","adaptation","stochastic","direction","transferring","variables","estimation","graphical","considering","asymptotic","likelihoods","distributed","canonical","likelihood","relaxation","neighborhood","estimates","consistent","hierarchical","represented","parameter","utilizing","demonstrate","interesting","detecting","procedure","strategies","inference","connections","hyperparameters","continuous","rightarrow","structure","statistical","hypothesis","reproducing","partially","estimator","unexpected","specification","interaction","guarantee","functions","estimating","generating","performance","consequences","constructs","processes","highlight","different","nonlinear","challenges","possesses","expensive","unprecedented","dimensional","selections","techniques","effective","thousands","impossible","simultaneously","computation","diversity","optimization","relatively","abundance","randomized","observations","previously","experiments","evaluations","represents","correlation","structural","formulation","straightforward","demonstrated","activation","resulting","applicability","classical","relationships","illustrating","implementations","variational","formulated","individual","extensions","alternative","outperforming","solutions","naturally","accurately","synthesized","generated","generative","adversarial","classification","converted","categories","supervision","empirically","embedding","discrimination","additional","descriptions","regularizers","traditional","specifically","available","consistently","recognize","additionally","engineered","regularization","capability","outperforms","benchmarks","generates","instances","annotations","annotated","illustrate","computational","representation","statistics","dimensionality","competitive","significantly","approximates","classifiers","comparing","partition","documents","explicitly","predictive","efficient","processing","furthermore","virtually","applications","resources","efficiently","explanations","regularity","considered","dependencies","crossings","syntactic","parsimonious","principle","sentences","practically","competing","investigate","languages","independent","dependency","transform","incorporates","introduce","nonsmooth","algorithm","knowledge","varepsilon","complexity","uncontaminated","contaminated","nonconvex","modification","flexibility","phenomena","attention","sequential","localized","extensively","detrimental","sequences","architectures","recurrent","increasing","operations"],"y":[16,24,3,12,8,59,114,1,137,6,14,30,62,7,125,61,43,62,118,63,14,121,194,66,61,12,2,108,16,57,18,24,67,68,107,80,120,36,571,79,68,107,99,233,62,12,109,0,327,184,63,8,46,25,5,14,82,28,175,56,92,922,9,20,91,30,731,55,115,4,52,5,179,2,405,253,28,16,97,142,45,301,62,6,23,77,90,617,48,59,73,83,68,17,96,39,146,40,92,72,6,38,61,45,105,43,97,38,160,60,57,20,163,116,94,526,13,79,55,76,129,20,99,35,10,154,155,308,48,61,54,7,85,51,254,85,49,86,61,69,87,302,385,52,61,138,274,10,115,74,26,74,68,62,403,309,149,6,409,79,163,15,9,126,56,1,45,1,49,69,17,32,143,107,131,56,62,33,338,1,811,368,0,221,0,5,13,22,28,28,174,79,6,34,2,107,128,160,95,67],"type":"bar"},{"x":["interpret","sometimes","disentangle","problematic","optimizer","magnitude","under ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4570,), (4570, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Object</span> <span style='background-color:rgba(0, 255, 0, 0.68944099378882);'>Recognition</span> <span style=''>Using</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>A</span> <span style=''>Survey</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.68944099378882);'>Recognition</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>using</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>is</span> <span style=''>an</span> <span style=''>active</span> <span style=''>area</span> <span style=''>of</span> <span style=''>research</span> <span style=''>and</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>breakthroughs</span> <span style=''>have</span> <span style=''>been</span> <span style=''>made</span> <span style=''>in</span> <span style=''>the</span> <span style=''>last</span> <span style=''>few</span> <span style=''>years</span> <span style=''>The</span> <span style=''>paper</span> <span style=''>attempts</span> <span style=''>to</span> <span style=''>indicate</span> <span style=''>how</span> <span style=''>far</span> <span style=''>this</span> <span style=''>field</span> <span style=''>has</span> <span style=''>progressed</span> <span style=''>The</span> <span style=''>paper</span> <span style=''>briefly</span> <span style='background-color:rgba(0, 255, 0, 0.47826086956521735);'>describes</span> <span style=''>the</span> <span style=''>history</span> <span style=''>of</span> <span style=''>research</span> <span style=''>in</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>and</span> <span style=''>describe</span> <span style=''>several</span> <span style=''>of</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>this</span> <span style=''>field</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3164556962025316);'>performances</span> <span style=''>of</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>Neural</span> <span style=''>Network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.34006734006734);'>benchmark</span> <span style=''>datasets</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>tabulated</span> <span style=''>Finally</span> <span style=''>some</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>this</span> <span style=''>field</span> <span style=''>have</span> <span style=''>been</span> <span style=''>provided</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>and</span> <span style=''>Parallel</span> <span style=''>Bayesian</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Effective</span> <span style=''>and</span> <span style=''>accurate</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>burden</span> <span style=''>required</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>that</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>stored</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processed</span> <span style=''>on</span> <span style=''>one</span> <span style=''>machine</span> <span style=''>Another</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>one</span> <span style=''>may</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encounter</span> <span style=''>is</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>outliers</span> <span style=''>and</span> <span style=''>contaminations</span> <span style=''>that</span> <span style=''>damage</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>quality</span> <span style=''>The</span> <span style=''>parallel</span> <span style=''>divide</span> <span style=''>and</span> <span style=''>conquer</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>strategy</span> <span style=''>divides</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>full</span> <span style=''>data</span> <span style=''>set</span> <span style=''>into</span> <span style=''>roughly</span> <span style=''>equal</span> <span style=''>subsets</span> <span style=''>and</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>and</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>on</span> <span style=''>each</span> <span style=''>subset</span> <span style=''>After</span> <span style=''>local</span> <span style=''>subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>this</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregates</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>or</span> <span style=''>other</span> <span style=''>modelvariable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>criteria</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>final</span> <span style=''>model</span> <span style=''>by</span> <span style=''>using ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4375);'>Dependence</span> <span style=''>Graph</span> <span style=''>of</span> <span style=''>Time</span> <span style=''>Series</span> <span style=''>with</span> <span style=''>Latent</span> <span style=''>Factors</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considers</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>from</span> <span style=''>samples</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>a</span> <span style=''>system</span> <span style=''>of</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3604336043360433);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equations</span> <span style=''>when</span> <span style=''>some</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3631578947368421);'>variables</span> <span style=''>are</span> <span style=''>latent</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>observe</span> <span style=''>the</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.4202898550724638);'>evolution</span> <span style=''>of</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3631578947368421);'>variables</span> <span style=''>and</span> <span style=''>never</span> <span style=''>observe</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3631578947368421);'>variables</span> <span style=''>from</span> <span style=''>this</span> <span style=''>we</span> <span style=''>would</span> <span style=''>like</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>between</span> <span style=''>the</span> <span style=''>observed</span> <span style='background-color:rgba(255, 0, 0, 0.3631578947368421);'>variables</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separating</span> <span style=''>out</span> <span style=''>the</span> <span style=''>spurious</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>caused</span> <span style=''>by</span> <span style=''>the</span> <span style=''>(marginalizing</span> <span style=''>out</span> <span style=''>of</span> <span style=''>the)</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3631578947368421);'>variables</span> <span style=''>time</span> <span style=''>series</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>to</span> <span style=''>do</span> <span style=''>so</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>when</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3631578947368421);'>variables</span> <span style=''>is</span> <span style=''>smaller</span> <span style=''>than</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>observed</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Resting</span> <span style=''>state</span> <span style=''>fMRI</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connectivity</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <br/><br/><span style=''>Machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>have</span> <span style=''>become</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasingly</span> <span style=''>popular</span> <span style=''>in</span> <span style=''>the</span> <span style=''>field</span> <span style=''>of</span> <span style=''>resting</span> <span style=''>state</span> <span style=''>fMRI</span> <span style=''>(functional</span> <span style=''>magnetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resonance</span> <span style=''>imaging)</span> <span style=''>network</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>networks</span> <span style=''>has</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>only</span> <span style=''>very</span> <span style=''>recently</span> <span style=''>and</span> <span style=''>has</span> <span style=''>remained</span> <span style=''>largely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unexplored</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connectome</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connectome</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>(CCNN)</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>a</span> <span style=''>publicly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>dataset</span> <span style=''>for</span> <span style=''>amnestic</span> <span style=''>mild</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cognitive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>impairment</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>our</span> <span style=''>CCNN</span> <span style=''>model</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinguish</span> <span style=''>between</span> <span style=''>subject</span> <span style=''>groups</span> <span style=''>We</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.13175796634443251)
# 	experimental (0.1364124597207304)
# 	segmentation (0.07268170426065163)
# 	representation (0.13784461152882205)
# 	architecture (0.09058360186179736)
# 	different (0.26172574292875045)
# 	detection (0.11385606874328678)
# 	information (0.2627998567848192)
# 	convolutional (0.13820264948084496)
# 	recognition (0.1460794844253491)
#
# Some Statistics words are:
# 	variables (0.1290483308420528)
# 	variational (0.10762331838565023)
# 	statistical (0.1554559043348281)
# 	algorithm (0.38066766317887396)
# 	estimation (0.1639262580966617)
# 	theoretical (0.15097159940209268)
# 	distribution (0.18285999003487793)
# 	inference (0.20378674638764324)
# 	dimensional (0.18535127055306427)
# 	regression (0.17887394120577976)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="24a4ab60-55f9-43e0-9503-c238178d0b3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24a4ab60-55f9-43e0-9503-c238178d0b3c")) {                    Plotly.newPlot(                        "24a4ab60-55f9-43e0-9503-c238178d0b3c",                        [{"x":["interpret","sometimes","disentangle","problematic","optimizer","magnitude","underlying","exceedingly","combination","isolation","practitioners","gradients","community","completing","generalization","mechanisms","determined","adaptation","stochastic","direction","transferring","variables","estimation","graphical","considering","asymptotic","likelihoods","distributed","canonical","likelihood","relaxation","neighborhood","estimates","consistent","hierarchical","represented","parameter","utilizing","demonstrate","interesting","detecting","procedure","strategies","inference","connections","hyperparameters","continuous","rightarrow","structure","statistical","hypothesis","reproducing","partially","estimator","unexpected","specification","interaction","guarantee","functions","estimating","generating","performance","consequences","constructs","processes","highlight","different","nonlinear","challenges","possesses","expensive","unprecedented","dimensional","selections","techniques","effective","thousands","impossible","simultaneously","computation","diversity","optimization","relatively","abundance","randomized","observations","previously","experiments","evaluations","represents","correlation","structural","formulation","straightforward","demonstrated","activation","resulting","applicability","classical","relationships","illustrating","implementations","variational","formulated","individual","extensions","alternative","outperforming","solutions","naturally","accurately","synthesized","generated","generative","adversarial","classification","converted","categories","supervision","empirically","embedding","discrimination","additional","descriptions","regularizers","traditional","specifically","available","consistently","recognize","additionally","engineered","regularization","capability","outperforms","benchmarks","generates","instances","annotations","annotated","illustrate","computational","representation","statistics","dimensionality","competitive","significantly","approximates","classifiers","comparing","partition","documents","explicitly","predictive","efficient","processing","furthermore","virtually","applications","resources","efficiently","explanations","regularity","considered","dependencies","crossings","syntactic","parsimonious","principle","sentences","practically","competing","investigate","languages","independent","dependency","transform","incorporates","introduce","nonsmooth","algorithm","knowledge","varepsilon","complexity","uncontaminated","contaminated","nonconvex","modification","flexibility","phenomena","attention","sequential","localized","extensively","detrimental","sequences","architectures","recurrent","increasing","operations","information","computations","experimentally","evaluation","dramatically","approximation","practical","decompositions","established","algorithms","extraction","decomposition","multilinear","alleviates","approaches","physically","nonnegativity","efficiency","developed","disadvantages","components","meaningful","synthetic","preserving","substantially","incorporating","uniqueness","simulation","nonnegative","approximations","reconstruction","shortcomings","autoencoders","improving","distribution","structures","posterior","complicated","intermediate","tremendous","conditional","transformations","experimental","parallelization","important","penalties","successful","synchronously","unsuccessful","implementing","reduction","considerably", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	rightarrow
# 	varepsilon
# 	uncontaminated
# 	collinearity
# 	unequally
# 	misspecification
# 	precisions
# 	occasionally
# 	unavoidably
# 	straggler
# 	confounder
# 	morgenstern
# 	subsamples
# 	behaviorally
# 	decouples
# 	preconditioned
# 	representer
# 	transplantation
# 	infection
# 	bacterial
# Some words which never appear in Statistics papers:
# 	syntactic
# 	nonnegativity
# 	consistencies
# 	prematurely
# 	coevolution
# 	instruction
# 	navigation
# 	generations
# 	morphemes
# 	controllers
# 	corroborated
# 	regulariser
# 	predicating
# 	strengthens
# 	exchanging
# 	axiomatizations
# 	geotagged
# 	geolocation
# 	recognizer
# 	integrity

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.076923076923077e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7583333333333333
